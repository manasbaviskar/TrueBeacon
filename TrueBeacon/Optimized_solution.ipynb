# %% [markdown]
# ## True Beacon Assignment Updated

# %% [markdown]
# ### Importing Relevant libraries

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date
import datetime as datetime
import warnings
import timeit
# %matplotlib inline
warnings.filterwarnings('ignore')
# Out:
# C:\Users\MANAS\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\MANAS\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\MANAS\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ### Extracting/Formatting the CSV files

# %%
index_df = pd.read_csv("Index_Subset.csv")
scores_df = pd.read_csv("Scores_Subset.csv")
scores_df['Unnamed: 0'] = pd.to_datetime(scores_df['Unnamed: 0'], format = '%Y-%m-%d')
scores_df = scores_df.set_index('Unnamed: 0')
scores_df.index  = scores_df.index.strftime("%d-%m-20%y")
index_df = index_df.set_index('Unnamed: 0')

cols = []
for i in scores_df.columns:
    #scores_df[i] = i
    cols.append(i)
    
a = scores_df.copy()
for col in scores_df.columns:
    a[col].values[:] = 0

# %% [markdown]
# ### Output :

# %%
# %%timeit
for i in a.columns:    
    booldf = index_df.isin([i]) 
    a[i].loc[booldf.loc[booldf.values == 1].index.tolist()] = 1
# Out:
# 9.56 s ± 866 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
a
# Out:
#             1958850D IS Equity  63MOONS IS Equity  ABB IS Equity  \
# Unnamed: 0
# 02-01-2012                 0.0                0.0            0.0
# 03-01-2012                 0.0                0.0            0.0
# 04-01-2012                 0.0                0.0            0.0
# 05-01-2012                 0.0                0.0            0.0
# 06-01-2012                 0.0                0.0            0.0
# ...                        ...                ...            ...
# 18-03-2020                 0.0                0.0            0.0
# 19-03-2020                 0.0                0.0            0.0
# 20-03-2020                 0.0                0.0            0.0
# 23-03-2020                 0.0                0.0            0.0
# 24-03-2020                 0.0                0.0            0.0
#
#             ABCAP IS Equity  ABFRL IS Equity  ABNL IS Equity  ACC IS Equity  \
# Unnamed: 0
# 02-01-2012              0.0              0.0             0.0            0.0
# 03-01-2012              0.0              0.0             0.0            0.0
# 04-01-2012              0.0              0.0             0.0            0.0
# 05-01-2012              0.0              0.0             0.0            0.0
# 06-01-2012              0.0              0.0             0.0            0.0
# ...                     ...              ...             ...            ...
# 18-03-2020              0.0              0.0             0.0            0.0
# 19-03-2020              0.0              0.0             0.0            0.0
# 20-03-2020              0.0              0.0             0.0            0.0
# 23-03-2020              0.0              0.0             0.0            0.0
# 24-03-2020              0.0              0.0             0.0            0.0
#
#             ACEM IS Equity  ADANI IS Equity  ADANIGR IS Equity  ...  \
# Unnamed: 0                                                      ...
# 02-01-2012             0.0              0.0                0.0  ...
# 03-01-2012             0.0              0.0                0.0  ...
# 04-01-2012             0.0              0.0                0.0  ...
# 05-01-2012             0.0              0.0                0.0  ...
# 06-01-2012             0.0              0.0                0.0  ...
# ...                    ...              ...                ...  ...
# 18-03-2020             0.0              0.0                0.0  ...
# 19-03-2020             0.0              0.0                0.0  ...
# 20-03-2020             0.0              0.0                0.0  ...
# 23-03-2020             0.0              0.0                0.0  ...
# 24-03-2020             0.0              0.0                0.0  ...
#
#             VYSB IS Equity  WHIRL IS Equity  WLCO IS Equity  WLSI IS Equity  \
# Unnamed: 0
# 02-01-2012             0.0              0.0             0.0             0.0
# 03-01-2012             0.0              0.0             0.0             0.0
# 04-01-2012             0.0              0.0             0.0             0.0
# 05-01-2012             0.0              0.0             0.0             0.0
# 06-01-2012             0.0              0.0             0.0             0.0
# ...                    ...              ...             ...             ...
# 18-03-2020             0.0              0.0             0.0             0.0
# 19-03-2020             0.0              0.0             0.0             0.0
# 20-03-2020             0.0              0.0             0.0             0.0
# 23-03-2020             0.0              0.0             0.0             0.0
# 24-03-2020             0.0              0.0             0.0             0.0
#
#             WPL IS Equity  WPRO IS Equity  YES IS Equity  Z IS Equity  \
# Unnamed: 0
# 02-01-2012            0.0             0.0            0.0          0.0
# 03-01-2012            0.0             0.0            0.0          0.0
# 04-01-2012            0.0             0.0            0.0          0.0
# 05-01-2012            0.0             0.0            0.0          0.0
# 06-01-2012            0.0             0.0            0.0          0.0
# ...                   ...             ...            ...          ...
# 18-03-2020            0.0             0.0            0.0          0.0
# 19-03-2020            0.0             0.0            0.0          0.0
# 20-03-2020            0.0             0.0            0.0          0.0
# 23-03-2020            0.0             0.0            0.0          0.0
# 24-03-2020            0.0             0.0            0.0          0.0
#
#             ZOMATO IS Equity  ZYDUSLIF IS Equity
# Unnamed: 0
# 02-01-2012               0.0                 0.0
# 03-01-2012               0.0                 0.0
# 04-01-2012               0.0                 0.0
# 05-01-2012               0.0                 0.0
# 06-01-2012               0.0                 0.0
# ...                      ...                 ...
# 18-03-2020               0.0                 0.0
# 19-03-2020               0.0                 0.0
# 20-03-2020               0.0                 0.0
# 23-03-2020               0.0                 0.0
# 24-03-2020               0.0                 0.0
#
# [2038 rows x 375 columns]
